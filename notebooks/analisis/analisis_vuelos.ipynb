# %%
{
 "cells": [
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "# Análisis Exploratorio de Datos de Vuelos\n",
    "\n",
    "## Objetivo\n",
    "Analizar patrones temporales y distribución de vuelos para determinar:\n",
    "- Horas pico y valle\n",
    "- Patrones semanales\n",
    "- Distribución mensual\n",
    "- Capacidad aeroportuaria"
   ]
  },
  {
   "cell_type": "code",
   #"execution_count": null,
   "metadata": {},
   "source": [
    "import pandas as pd\n",
    "import numpy as np\n",
    "import matplotlib.pyplot as plt\n",
    "import seaborn as sns\n",
    "from sqlalchemy import create_engine\n",
    "import plotly.express as px\n",
    "import plotly.graph_objects as go\n",
    "\n",
    "# Configurar visualización\n",
    "plt.style.use('seaborn')\n",
    "sns.set_palette('husl')"
   ]
  },
  {
   "cell_type": "code",
   "metadata": {},
   "source": [
    "# Conexión a la base de datos\n",
    "engine = create_engine('postgresql://postgres:Iforero2011.@localhost:5432/flights')\n",
    "\n",
    "# Cargar datos\n",
    "query = \"SELECT * FROM public.fligths\"\n",
    "df = pd.read_sql(query, engine)"
   ]
  },
  {
   "cell_type": "code",
   "metadata": {},
   "source": [
    "# Procesamiento inicial de fechas\n",
    "df['hora'] = pd.to_datetime(df['hora_salida']).dt.hour\n",
    "df['dia_semana'] = pd.to_datetime(df['fecha_salida']).dt.day_name()\n",
    "df['mes'] = pd.to_datetime(df['fecha_salida']).dt.month\n",
    "\n",
    "# Mostrar información del dataset\n",
    "print(\"Información del Dataset:\")\n",
    "print(df.info())\n",
    "print(\"\\nPrimeras filas:\")\n",
    "print(df.head())"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "## Análisis de Horas Pico"
   ]
  },
  {
   "cell_type": "code",
   "metadata": {},
   "source": [
    "# Distribución de vuelos por hora\n",
    "plt.figure(figsize=(15, 6))\n",
    "sns.histplot(data=df, x='hora', bins=24)\n",
    "plt.title('Distribución de Vuelos por Hora')\n",
    "plt.xlabel('Hora del Día')\n",
    "plt.ylabel('Número de Vuelos')\n",
    "plt.show()"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "## Patrones Semanales"
   ]
  },
  {
   "cell_type": "code",
   "metadata": {},
   "source": [
    "# Distribución por día de la semana\n",
    "plt.figure(figsize=(12, 6))\n",
    "orden_dias = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']\n",
    "sns.countplot(data=df, x='dia_semana', order=orden_dias)\n",
    "plt.xticks(rotation=45)\n",
    "plt.title('Distribución de Vuelos por Día de la Semana')\n",
    "plt.xlabel('Día')\n",
    "plt.ylabel('Número de Vuelos')\n",
    "plt.show()"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "## Heatmap de Actividad"
   ]
  },
  {
   "cell_type": "code",
   "metadata": {},
   "source": [
    "# Crear heatmap de actividad por hora y día\n",
    "pivot_table = pd.crosstab(df['hora'], df['dia_semana'])\n",
    "plt.figure(figsize=(12, 8))\n",
    "sns.heatmap(pivot_table, cmap='YlOrRd', annot=True, fmt='d')\n",
    "plt.title('Heatmap de Vuelos por Hora y Día')\n",
    "plt.xlabel('Día de la Semana')\n",
    "plt.ylabel('Hora del Día')\n",
    "plt.show()"
   ]
  }
 ],
 "metadata": {
  "kernelspec": {
   "display_name": "Python 3",
   "language": "python",
   "name": "python3"
  }
 },
 "nbformat": 4,
 "nbformat_minor": 2
}
# Out:
# {'cells': [{'cell_type': 'markdown',
#    'metadata': {},
#    'source': ['# Análisis Exploratorio de Datos de Vuelos\n',
#     '\n',
#     '## Objetivo\n',
#     'Analizar patrones temporales y distribución de vuelos para determinar:\n',
#     '- Horas pico y valle\n',
#     '- Patrones semanales\n',
#     '- Distribución mensual\n',
#     '- Capacidad aeroportuaria']},
#   {'cell_type': 'code',
#    'metadata': {},
#    'source': ['import pandas as pd\n',
#     'import numpy as np\n',
#     'import matplotlib.pyplot as plt\n',
#     'import seaborn as sns\n',
#     'from sqlalchemy import create_engine\n',
#     'import plotly.express as px\n',
#     'import plotly.graph_objects as go\n',
#     '\n',
#     '# Configurar visualización\n',
#     "plt.style.use('seaborn')\n",
#     "sns.set_palette('husl')"]},
#   {'cell_type': 'code',
#    'metadata': {},
#    'source': ['# Conexión a la base de datos\n',
#     "engine = create_engine('postgresql://postgres:Iforero2011.@localhost:5432/flights')\n",
#     '\n',
#     '# Cargar datos\n',
#     'query = "SELECT * FROM public.fligths"\n',
#     'df = pd.read_sql(query, engine)']},
#   {'cell_type': 'code',
#    'metadata': {},
#    'source': ['# Procesamiento inicial de fechas\n',
#     "df['hora'] = pd.to_datetime(df['hora_salida']).dt.hour\n",
#     "df['dia_semana'] = pd.to_datetime(df['fecha_salida']).dt.day_name()\n",
#     "df['mes'] = pd.to_datetime(df['fecha_salida']).dt.month\n",
#     '\n',
#     '# Mostrar información del dataset\n',
#     'print("Información del Dataset:")\n',
#     'print(df.info())\n',
#     'print("\\nPrimeras filas:")\n',
#     'print(df.head())']},
#   {'cell_type': 'markdown',
#    'metadata': {},
#    'source': ['## Análisis de Horas Pico']},
#   {'cell_type': 'code',
#    'metadata': {},
#    'source': ['# Distribución de vuelos por hora\n',
#     'plt.figure(figsize=(15, 6))\n',
#     "sns.histplot(data=df, x='hora', bins=24)\n",
#     "plt.title('Distribución de Vuelos por Hora')\n",
#     "plt.xlabel('Hora del Día')\n",
#     "plt.ylabel('Número de Vuelos')\n",
#     'plt.show()']},
#   {'cell_type': 'markdown',
#    'metadata': {},
#    'source': ['## Patrones Semanales']},
#   {'cell_type': 'code',
#    'metadata': {},
#    'source': ['# Distribución por día de la semana\n',
#     'plt.figure(figsize=(12, 6))\n',
#     "orden_dias = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']\n",
#     "sns.countplot(data=df, x='dia_semana', order=orden_dias)\n",
#     'plt.xticks(rotation=45)\n',
#     "plt.title('Distribución de Vuelos por Día de la Semana')\n",
#     "plt.xlabel('Día')\n",
#     "plt.ylabel('Número de Vuelos')\n",
#     'plt.show()']},
#   {'cell_type': 'markdown',
#    'metadata': {},
#    'source': ['## Heatmap de Actividad']},
#   {'cell_type': 'code',
#    'metadata': {},
#    'source': ['# Crear heatmap de actividad por hora y día\n',
#     "pivot_table = pd.crosstab(df['hora'], df['dia_semana'])\n",
#     'plt.figure(figsize=(12, 8))\n',
#     "sns.heatmap(pivot_table, cmap='YlOrRd', annot=True, fmt='d')\n",
#     "plt.title('Heatmap de Vuelos por Hora y Día')\n",
#     "plt.xlabel('Día de la Semana')\n",
#     "plt.ylabel('Hora del Día')\n",
#     'plt.show()']}],
#  'metadata': {'kernelspec': {'display_name': 'Python 3',
#    'language': 'python',
#    'name': 'python3'}},
#  'nbformat': 4,
#  'nbformat_minor': 2}

# %%
{
 "cells": [
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "# Análisis Exploratorio de Datos de Vuelos\n",
    "\n",
    "## Objetivo\n",
    "Analizar patrones temporales y distribución de vuelos para determinar:\n",
    "- Horas pico y valle\n",
    "- Patrones semanales\n",
    "- Distribución mensual\n",
    "- Capacidad aeroportuaria"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "source": [
    "import pandas as pd\n",
    "import numpy as np\n",
    "import matplotlib.pyplot as plt\n",
    "import seaborn as sns\n",
    "from sqlalchemy import create_engine\n",
    "import plotly.express as px\n",
    "import plotly.graph_objects as go\n",
    "\n",
    "# Configurar visualización\n",
    "plt.style.use('seaborn')\n",
    "sns.set_palette('husl')"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "source": [
    "# Conexión a la base de datos\n",
    "engine = create_engine('postgresql://postgres:Iforero2011.@localhost:5432/flights')\n",
    "\n",
    "# Cargar datos\n",
    "query = \"SELECT * FROM public.fligths\"\n",
    "df = pd.read_sql(query, engine)"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "source": [
    "# Procesamiento inicial de fechas\n",
    "df['hora'] = pd.to_datetime(df['hora_salida']).dt.hour\n",
    "df['dia_semana'] = pd.to_datetime(df['fecha_salida']).dt.day_name()\n",
    "df['mes'] = pd.to_datetime(df['fecha_salida']).dt.month\n",
    "\n",
    "# Mostrar información del dataset\n",
    "print(\"Información del Dataset:\")\n",
    "print(df.info())\n",
    "print(\"\\nPrimeras filas:\")\n",
    "print(df.head())"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "## Análisis de Horas Pico"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "source": [
    "# Distribución de vuelos por hora\n",
    "plt.figure(figsize=(15, 6))\n",
    "sns.histplot(data=df, x='hora', bins=24)\n",
    "plt.title('Distribución de Vuelos por Hora')\n",
    "plt.xlabel('Hora del Día')\n",
    "plt.ylabel('Número de Vuelos')\n",
    "plt.show()"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "## Patrones Semanales"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "source": [
    "# Distribución por día de la semana\n",
    "plt.figure(figsize=(12, 6))\n",
    "orden_dias = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']\n",
    "sns.countplot(data=df, x='dia_semana', order=orden_dias)\n",
    "plt.xticks(rotation=45)\n",
    "plt.title('Distribución de Vuelos por Día de la Semana')\n",
    "plt.xlabel('Día')\n",
    "plt.ylabel('Número de Vuelos')\n",
    "plt.show()"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "## Heatmap de Actividad"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "source": [
    "# Crear heatmap de actividad por hora y día\n",
    "pivot_table = pd.crosstab(df['hora'], df['dia_semana'])\n",
    "plt.figure(figsize=(12, 8))\n",
    "sns.heatmap(pivot_table, cmap='YlOrRd', annot=True, fmt='d')\n",
    "plt.title('Heatmap de Vuelos por Hora y Día')\n",
    "plt.xlabel('Día de la Semana')\n",
    "plt.ylabel('Hora del Día')\n",
    "plt.show()"
   ]
  }
 ],
 "metadata": {
  "kernelspec": {
   "display_name": "Python 3",
   "language": "python",
   "name": "python3"
  }
 },
 "nbformat": 4,
 "nbformat_minor": 2
}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 19
#       1 {
#       2  "cells": [
#       3   {
#       4    "cell_type": "markdown",
#       5    "metadata": {},
#       6    "source": [
#       7     "# Análisis Exploratorio de Datos de Vuelos\n",
#       8     "\n",
#       9     "## Objetivo\n",
#      10     "Analizar patrones temporales y distribución de vuelos para determinar:\n",
#      11     "- Horas pico y valle\n",
#      12     "- Patrones semanales\n",
#      13     "- Distribución mensual\n",
#      14     "- Capacidad aeroportuaria"
#      15    ]
#      16   },
#      17   {
#      18    "cell_type": "code",
# ---> 19    "execution_count": null,
#      20    "metadata": {},
#      21    "source": [
#      22     "import pandas as pd\n",
#      23     "import numpy as np\n",
#      24     "import matplotlib.pyplot as plt\n",
#      25     "import seaborn as sns\n",
#      26     "from sqlalchemy import create_engine\n",
#      27     "import plotly.express as px\n",
#      28     "import plotly.graph_objects as go\n",
#      29     "\n",
#      30     "# Configurar visualización\n",
#      31     "plt.style.use('seaborn')\n",
#      32     "sns.set_palette('husl')"
#      33    ]
#      34   },
#      35   {
#      36    "cell_type": "code",
#      37    "execution_count": null,
#      38    "metadata": {},
#      39    "source": [
#      40     "# Conexión a la base de datos\n",
#      41     "engine = create_engine('postgresql://postgres:Iforero2011.@localhost:5432/flights')\n",
#      42     "\n",
#      43     "# Cargar datos\n",
#      44     "query = \"SELECT * FROM public.fligths\"\n",
#      45     "df = pd.read_sql(query, engine)"
#      46    ]
#      47   },
#      48   {
#      49    "cell_type": "code",
#      50    "execution_count": null,
#      51    "metadata": {},
#      52    "source": [
#      53     "# Procesamiento inicial de fechas\n",
#      54     "df['hora'] = pd.to_datetime(df['hora_salida']).dt.hour\n",
#      55     "df['dia_semana'] = pd.to_datetime(df['fecha_salida']).dt.day_name()\n",
#      56     "df['mes'] = pd.to_datetime(df['fecha_salida']).dt.month\n",
#      57     "\n",
#      58     "# Mostrar información del dataset\n",
#      59     "print(\"Información del Dataset:\")\n",
#      60     "print(df.info())\n",
#      61     "print(\"\\nPrimeras filas:\")\n",
#      62     "print(df.head())"
#      63    ]
#      64   },
#      65   {
#      66    "cell_type": "markdown",
#      67    "metadata": {},
#      68    "source": [
#      69     "## Análisis de Horas Pico"
#      70    ]
#      71   },
#      72   {
#      73    "cell_type": "code",
#      74    "execution_count": null,
#      75    "metadata": {},
#      76    "source": [
#      77     "# Distribución de vuelos por hora\n",
#      78     "plt.figure(figsize=(15, 6))\n",
#      79     "sns.histplot(data=df, x='hora', bins=24)\n",
#      80     "plt.title('Distribución de Vuelos por Hora')\n",
#      81     "plt.xlabel('Hora del Día')\n",
#      82     "plt.ylabel('Número de Vuelos')\n",
#      83     "plt.show()"
#      84    ]
#      85   },
#      86   {
#      87    "cell_type": "markdown",
#      88    "metadata": {},
#      89    "source": [
#      90     "## Patrones Semanales"
#      91    ]
#      92   },
#      93   {
#      94    "cell_type": "code",
#      95    "execution_count": null,
#      96    "metadata": {},
#      97    "source": [
#      98     "# Distribución por día de la semana\n",
#      99     "plt.figure(figsize=(12, 6))\n",
#     100     "orden_dias = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']\n",
#     101     "sns.countplot(data=df, x='dia_semana', order=orden_dias)\n",
#     102     "plt.xticks(rotation=45)\n",
#     103     "plt.title('Distribución de Vuelos por Día de la Semana')\n",
#     104     "plt.xlabel('Día')\n",
#     105     "plt.ylabel('Número de Vuelos')\n",
#     106     "plt.show()"
#     107    ]
#     108   },
#     109   {
#     110    "cell_type": "markdown",
#     111    "metadata": {},
#     112    "source": [
#     113     "## Heatmap de Actividad"
#     114    ]
#     115   },
#     116   {
#     117    "cell_type": "code",
#     118    "execution_count": null,
#     119    "metadata": {},
#     120    "source": [
#     121     "# Crear heatmap de actividad por hora y día\n",
#     122     "pivot_table = pd.crosstab(df['hora'], df['dia_semana'])\n",
#     123     "plt.figure(figsize=(12, 8))\n",
#     124     "sns.heatmap(pivot_table, cmap='YlOrRd', annot=True, fmt='d')\n",
#     125     "plt.title('Heatmap de Vuelos por Hora y Día')\n",
#     126     "plt.xlabel('Día de la Semana')\n",
#     127     "plt.ylabel('Hora del Día')\n",
#     128     "plt.show()"
#     129    ]
#     130   }
#     131  ],
#     132  "metadata": {
#     133   "kernelspec": {
#     134    "display_name": "Python 3",
#     135    "language": "python",
#     136    "name": "python3"
#     137   }
#     138  },
#     139  "nbformat": 4,
#     140  "nbformat_minor": 2
#     141 }
#
# NameError: name 'null' is not defined
